# %% [markdown]
# # Library of Models

# %%
import pyRVtest
pyRVtest.__version__
# Out:
# '0.4.0rc1'

# %% [markdown]
# Here, we document the library of conduct models supported by `pyRVtest`. Every model is a subclass of `pyRVtest.ConductModel`; you pass instances to `pyRVtest.Problem(models=[...])`. The current library includes:
#
# * Bertrand Competition with Differentiated Products
# * Cournot Competition with Differentiated Products
# * Monopoly (i.e., Perfect Collusion)
# * Bertrand and Cournot Competition with Profit Weights / Partial Collusion
# * Non-Profit Conduct Models
# * Marginal Cost Pricing (i.e., zero markup models)
# * Rule-of-Thumb Models (markup as a fixed multiple of cost)
# * Bertrand with Scaled Costs
# * Constant Markup Models (markups that do not vary with demand or cost)
# * Vertical Models
#
# We also detail two options for testing models outside this library: a Python callable for closed-form markups (`CustomConductModel`), and pre-computed markup columns (`UserSuppliedMarkups`).

# %% [markdown]
# ## Preliminaries and notation
#
# Throughout, we consider settings in which potentially multi-product firms, indexed by $f$ compete across markets, indexed by $t$. In each market, there are $J_t$ products offered. Each firm $f$ offers a distinct subset of those products, $\mathcal{J}_{ft}$. We use the $jt$ index to denote observations at the product-market level, and we use the $t$ index to denote the vector which stacks all $J_t$ observations in market $t$. Demand for product $j$ in market $t$, which depends on $p_t$, the price of all products in the market, is denoted $s_{jt}(p_t)$. Realizations of market shares across products in market $t$ at the equilibrium prices $p_t$ are denoted $s_t$. We denote the $J_t \times J_t$ matrix of own- and cross-price derivatives as $\frac{\partial s_t}{\partial p_t}$, so that the $(j,k)$-th element denotes the marginal effect of an increase in the price of product $k$ on the market share of product $j$.
#
# The researcher observes, in each market $t$, realizations of equilibrium prices and shares for a true model of conduct which generated the data: $p_t$ and $s_t$. The researcher does not know the true model, but wishes to test a menu of models, $M$. For each model $m$ in the menu, the stacked first order condition in market $t$ can be expressed as:
#
# \begin{equation}
# p_t - c_{mt} = \Delta_{mt}
# \end{equation}
#
# Here, $\Delta_{mt}$ are the stacked markups implied by model $m$ in market $t$. For the models we consider, the markups $\Delta_{mt}$ can be expressed as known functions of prices and exogenous variables and typically depend on the demand system. Thus, given equilibrium outcomes, the known market structure (i.e., which firm sells which products), and the demand system, $\Delta_{mt}$ can be computed. $c_{mt}$ are the marginal costs implied by the model which satisfy the system of first order conditions.
#
# To specify a menu of models in pyRVtest, the researcher creates a `ConductModel` class for each of the models in the menu when defining the testing problem.  In what follows, we show how to specify the `ConductModel` class for the class of models that the code can currently handle.

# %% [markdown]
# ## Bertrand Competition: $m=B$
#
# Suppose the researcher wants to include in the menu of models the Bertrand-Nash model of competition in prices. In market $t$, firm $f$ sets prices for all $j\in\mathcal{J}_{ft}$ to maximize the sum of its profits across those products. Letting $p_{ft}$ be the vector of those prices, the firm solves:
#
# \begin{equation}
# \max_{p_{ft}} \sum_{j\in\mathcal{J}_{ft}} (p_{jt} - c_{jt}) s_{jt}(p_{t})
# \end{equation}
#
# The stacked first-order conditions across firms in market $t$ can be written as $(p_{t} - c_{t}) = \Delta_{Bt}$ where $\Delta_{Bt}$ is:
#
# \begin{equation}
# \Delta_{Bt} \quad = \quad \left(\Omega_t \odot \frac{\partial s_t}{\partial p_t} \right)^{-1}s_t.
# \end{equation}
#
# Here, $\Omega_t$ is the standard $J_t\times J_t$ ownership matrix so that the $(j,k)$-th element is 1 if products $j$ and $k$ are sold by the same firm, and 0 otherwise. Furthermore, $\odot$ denotes element-by-element multiplication.
#
# To include Bertrand as one of the models to test with pyRVtest, the researcher must include in the `product_data` a column for which each row indicates the identity of the firm selling the corresponding product. If that column is named `firm_ids`, then the Bertrand model can be specified with the following `ConductModel` class.

# %%
model = pyRVtest.Bertrand(ownership='firm_ids')

# %% [markdown]
# Each conduct class takes an `ownership` argument naming the column in `product_data` from which the per-market ownership matrix is built. The `Vertical` wrapper covered later combines two conduct instances with their own `ownership` arguments for the downstream and upstream tiers respectively.

# %% [markdown]
# ## Monopoly (i.e., Perfect Collusion): $m=M$
#
# Now suppose that in market $t$, prices $p_{jt}$ are chosen to maximize the sum of its profits across all products in market $t$, or:
#
# \begin{equation}
# \max_{p_{t}} \sum_{j\in \mathcal{J}_{t}} (p_{jt} - c_{jt}) s_{jt}(p_{t})
# \end{equation}
#
# This can arise in settings with more than one firm if the firms are perfectly colluding. The stacked first-order conditions across firms in market $t$ can be written as $(p_{t} - c_{t}) = \Delta_{Mt}$ where $\Delta_{Mt}$ is:
#
# \begin{equation}
# \Delta_{Mt} \quad = \quad \left(1_t \odot \frac{\partial s_t}{\partial p_t} \right)^{-1}s_t.
# \end{equation}
#
# Here, $1_t$ is a $J_t\times J_t$ matrix of ones.
#
# The researcher can specify Monopoly as one of the models to test with pyRVtest, using the following `ConductModel` class.  Note that here, if the researcher was to include a ownership_downstream option, the package will override this and build the ownership matrix in each market as a matrix of ones.

# %%
model = pyRVtest.Monopoly()

# %% [markdown]
# ## Cournot Competition with Differentiated Products: $m=C$
#
# Suppose the researcher wants to include in the menu of models Cournot competition (quantity-setting) with differentiated products, in which each firm simultaneously chooses market shares for its $\mathcal{J}_{ft}$ products,  $s_{ft}$, to maximize:
#
# \begin{equation}
# \max_{s_{ft}} \sum_{j\in \mathcal{J}_{ft}} s_{jt} (p_{jt}(s_t) - c_{jt})
# \end{equation}
#
# where $p_{jt}(s_t)$ represents inverse demand for product $j$ in market $t$.  The stacked first-order conditions are $p_{jt} - c_{jt} = \Delta_{Ct}$ where $\Delta_{Ct}$ is:
#
# \begin{equation}
# \Delta_{Ct} \quad = \quad \left(\Omega_t \odot \left(\frac{\partial s_t}{\partial p_t} \right)^{-1}\right)s_t.
# \end{equation}
#
# Here, $\Omega_t$ is the standard $J_t\times J_t$ ownership matrix so that the $(j,k)$-th element is 1 if product $j$ and $k$ are sold by the same firm, and 0 otherwise.  Furthermore, $\odot$ denotes element-by-element multiplication.
#
# To include Cournot as one of the models to test with pyRVtest, the researcher must include in the `product_data` a column for which the i-th row indicates the identity of the firm selling the corresponding product.  If that column is named `firm_ids`, then the Cournot model can be specified with the following `ConductModel` class.

# %%
model = pyRVtest.Cournot(ownership='firm_ids')

# %% [markdown]
# ## Bertrand and Cournot with Profit Weights / Partial Collusion: $m=PW(\lambda)$
#
# Suppose the researcher wants to include in the menu of models either price or quantity competition where firms partially internalize the effect of their actions on rivals' profits. This can occur, for example, in a model of common ownership (e.g., :ref:`references: Backus, Conlon, and Sinkinson (2022)`) or imperfect collusion (e.g., :ref:`references: Miller and Weinberg (2017)`). The first-order conditions then contain an ownership matrix in which the $(j,k)$-th element is $\lambda_{jk}$ rather than $\{0, 1\}$.
#
# For the Bertrand variant, the v0.4 class is `PartialCollusion`, which takes the same `ownership` and a `kappa_specification` argument:

# %%
kappa_specification = 1
model = pyRVtest.PartialCollusion(ownership='firm_ids', kappa_specification=kappa_specification)

# %% [markdown]
# For the Cournot variant, pass the same `kappa_specification` to the standard `Cournot` class:

# %%
model = pyRVtest.Cournot(ownership='firm_ids', kappa_specification=kappa_specification)

# %% [markdown]
# Additionally, profit weights can depend on observable parameters. For example, in $\textbf{Equation 10}$ of :ref:`references: Ciliberto and Williams (2014)` profit weights are defined as a function of the amount of multi-market contact between different airlines: $f(mmc, \phi)$. A model then corresponds to specific values of the parameters ($\phi$) in that function. For each such model, a researcher can first compute profit weights from the data on multi-market contact and a chosen $\phi$. Then, the researcher can use these profit weights to write a kappa specification that will be used in the construction of the ownership matrix. In this case, firm_ids should represent indices for this kappa specification (see additional details [here](https://pyblp.readthedocs.io/en/stable/_api/pyblp.build_ownership.html)).  For example, for a user-computed matrix `f_mcc`, `kappa_specification` could be written as follows:

# %%
import numpy as np
def kappa_specification(f, g):
    f_mmc = np.array([
        [1.0, 0.4, 0.3],
        [0.4, 1.0, 0.2],
        [0.3, 0.2, 1.0]
    ])
    return f_mmc[f, g]

# %% [markdown]
# ## Non-profit Conduct: $m=N(\lambda)$
#
# Suppose the researcher wants to model non-profit conduct where firms choose their own prices to maximize a weighted sum of profit and consumer surplus as in :ref:`references: Duarte, Magnolfi, and Roncoroni (2022)` -- non-profit firms place a weight of $1-\lambda \in (0,1)$ on welfare relative to profit. This adjusts the Bertrand FOC's ownership matrix so that the $(j,k)$-th element becomes $1/\lambda_{jk}$ when the firm selling products $j$ and $k$ is a non-profit.
#
# To test such a model with pyRVtest, use the `PartialCollusion` class with a custom `kappa_specification`:

# %%
model = pyRVtest.PartialCollusion(ownership='firm_ids', kappa_specification=kappa_specification)

# %% [markdown]
# ## Marginal Cost Pricing (Perfect Competition / Zero Markup): $m=PC$
#
# Consider a class of models where firms set prices equal to marginal cost so that markups are structurally zero, $\Delta_{PCt} = 0$. Use the `PerfectCompetition` class -- it takes no `ownership` argument because the ownership structure does not enter the FOC.

# %%
model = pyRVtest.PerfectCompetition()

# %% [markdown]
# ## Rule of Thumb Models: $m=R(\lambda)$
#
# Consider models where markups are a multiple of cost: $p_t = (1+\lambda) c_t$. The stacked first-order conditions are $p_t - c_t = \Delta_{Rt}$ where:
#
# \begin{equation}
# \Delta_{Rt} = \lambda c_t
# \end{equation}
#
# Equivalently:
#
# \begin{equation}
# \Delta_{Rt} = \frac{\lambda}{1+\lambda}p_t
# \end{equation}
#
# For the **uniform** case ($\lambda$ constant across firms and markets, equivalently $\varphi = 1 + \lambda$), v0.4 ships an ergonomic `RuleOfThumb(phi=...)` wrapper. For per-product variation, use `PerfectCompetition(cost_scaling='column_name')` where the named column lives in `product_data`:

# %%
# v0.4 ergonomic wrapper for a uniform multiplier (p = phi * mc):
model = pyRVtest.RuleOfThumb(phi=2.0)
# Per-product variation is still supported via the `cost_scaling` kwarg
# on PerfectCompetition (which accepts a column name in `product_data`):
lmbda = 'cost_scaling_column'
model = pyRVtest.PerfectCompetition(cost_scaling=lmbda)

# %% [markdown]
# ## Bertrand with Scaled Costs: $m = SC(\lambda)$
#
# Next, consider models where firms choose own prices in market $t$ to solve:
#
# \begin{equation}
# \max_{p_{ft}} \sum_{j\in\mathcal{J}_{ft}} (p_{jt} - \lambda c_{jt}) s_{jt}(p_{t})
# \end{equation}
#
# The stacked first-order conditions are $p_{t} - c_{t} = \Delta_{SCt}$ where:
#
# \begin{equation}
# \Delta_{SCt} = \Delta_{Bt}  + (1-\lambda) c_{t}
# \end{equation}
#
# and $\Delta_{Bt}$ are the Bertrand markups. These markups arise in :ref:`references: Harrington (2023)`, where firms collude via cost coordination, and in settings where firms maximize a weighted sum of profits and revenues. Specify with `Bertrand(cost_scaling='column_name')`:

# %%
lmbda = 'cost_scaling_column'
model = pyRVtest.Bertrand(ownership='firm_ids', cost_scaling=lmbda)

# %% [markdown]
# ## Constant Markup Models: $m = CM(\eta)$
#
# Consider models where the markup for each product $j$ in each market $t$ equals a constant $\eta_{jt}$ that does not depend on demand or cost:
#
# \begin{equation}
# \Delta_{CMjt} = \eta_{jt}
# \end{equation}
#
# Use the `ConstantMarkup` class. The constructor accepts either a scalar (uniform across products) or a column name in `product_data` containing per-product values. If the column is named `eta`:

# %%
# v0.4 dedicated class for constant per-product markups:
model = pyRVtest.ConstantMarkup(markup='eta')
# (UserSuppliedMarkups also works and is the right choice when the
# precomputed values come from somewhere other than a constant-markup
# hypothesis -- see the bottom of this page.)

# %% [markdown]
# ## Vertical Models with unobserved wholesale costs
#
# Now we consider models with vertical interactions between retailers and wholesalers (denoted with superscript $r$ and $w$ respectively). Consider the simple linear pricing model from :ref:`references: Villas-Boas (2007)` where wholesalers individually set wholesale prices $p^w_t$ to maximize their profits in market $t$, and, given $p^w_t$, retailers choose retail prices $p^r_t$ to maximize their profits. Assuming wholesale prices are unobserved, summing the stacked first-order conditions for wholesalers and retailers yields:
#
# \begin{equation}
# p^r_{t} - c^r_t - c^w_t = \Delta^r_{Bt} + \Delta^w_{Bt}
# \end{equation}
#
# where $\Delta^r_{Bt}$ are the retailer Bertrand markups and $\Delta^w_{Bt}$ are the wholesaler Bertrand markups. The package combines the two via the `Vertical` wrapper, which takes a downstream and an upstream `ConductModel` instance:

# %%
model = pyRVtest.Vertical(
    downstream=pyRVtest.Bertrand(ownership='retailer_ids'),
    upstream=pyRVtest.Bertrand(ownership='wholesaler_ids'),
)

# %% [markdown]
# The `downstream` and `upstream` arguments can each be any conduct class -- e.g., `Monopoly` downstream when each market corresponds to a single firm (the consumer-packaged-goods store-level case). Profit weights or non-profit conduct enter through `kappa_specification` on the inner classes, and `Vertical` accepts a `vertical_integration` argument identifying the partial-VI column. If that column is named `vi_id`:

# %%
model = pyRVtest.Vertical(
    downstream=pyRVtest.Bertrand(ownership='retailer_ids'),
    upstream=pyRVtest.Bertrand(ownership='wholesaler_ids'),
    vertical_integration='vi_id',
)

# %% [markdown]
# ## Options to Test Other Models
#
# If your model is not in the library above, two options:
#
# 1. If markups are a closed-form function of the ownership matrix, the response matrix, and shares, pass the function via `CustomConductModel(markup_fn=...)`. The callable signature is `f(ownership_matrix, response_matrix, shares)` and returns a markup vector. To recover Bertrand from this option:

# %%
import numpy as np

def bertrand_markup(ownership_matrix, response_matrix, shares):
    return -np.linalg.inv(ownership_matrix * response_matrix) @ shares

model = pyRVtest.CustomConductModel(
    markup_fn=bertrand_markup,
    ownership='firm_ids',
    name='bertrand',
)

# %% [markdown]
# 2. If your markups are not a known function of those inputs -- e.g., they come from a separate structural estimation, a calibration, or are pre-computed externally -- pass the column name via `UserSuppliedMarkups`:

# %%
model = pyRVtest.UserSuppliedMarkups('my_markups')

# %% [markdown]
# Please note, when using the option `user_specified_markups`, $\textbf{the code is not able to adjust}$ the pairwise RV test statistics, the model confidence set, and the pairwise F-statistics for the errors coming from demand estimation or for clustering.
